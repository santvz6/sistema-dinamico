# %% [markdown]
# # Trabajo Final: Dinámica y Control de un Dron Quadrotor

# %% [markdown]
# Este Notebook implementa la simulación en tiempo continuo de la dinámica no lineal de un Quadrotor (12 EDOs) y un controlador PD en cascada para lograr el hover estable en una posición deseada.

# %% [markdown]
# ## Configuración del Entorno y Librerías
# Instalamos librerías necesarias y cargamos las utilidades.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from mpl_toolkits.mplot3d import Axes3D
plt.style.use('seaborn-v0_8')

# %% [markdown]
# ## Ejecución del Sistema Dinámico

# %%
from main import main

main()
# Out:
# Generando Gráficas de Trayectoria y Errores...
# Simulación completada. Estado final Z: 522.60m
